# %%
import pandas as pd

# %%
bike_data = pd.read_csv('../data/processed_df.csv')

sorted_stations = []
for st_id in bike_data.start_id.sort_values().unique():
    sorted_stations.append(bike_data[bike_data.start_id==st_id])

sorted_stations
# Out:
# [         Unnamed: 0  start_id  end_id  start_time  duration  end_time  \
#  1511           1512         1      71    47286300       480  47286780
#  3497           3498         1       3    47290680      1200  47291880
#  5960           5961         1     330    47295840      1680  47297520
#  5976           5977         1     433    47295900       180  47296080
#  6446           6447         1     803    47297220       900  47298120
#  ...             ...       ...     ...         ...       ...       ...
#  3954400     3954401         1      63    56918700       480  56919180
#  3956057     3956058         1     189    56920920        60  56920980
#  3956177     3956178         1      63    56921160       540  56921700
#  3957039     3957040         1     386    56922600       780  56923380
#  3958363     3958364         1     326    56925600       180  56925780
#
#               dist
#  1511     1.718483
#  3497     1.964612
#  5960     4.997948
#  5976     0.673108
# ...
